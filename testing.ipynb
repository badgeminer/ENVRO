# %%
import datetime

# %%
A = datetime.datetime(2025,2,14,10,31)
B = datetime.datetime(2025,2,15,10,31)
C = datetime.datetime(2025,2,13,10,31)

# %%
B >= A
# Out:
# True

# %%
A >= C
# Out:
# True

# %%
C <= A
# Out:
# True

# %%
import requests

# Base URL for the GeoMet-OGC-API
base_url = "https://api.weather.gc.ca/collections"

# Endpoint for real-time meteorological bulletins (replace 'your_collection_name' with the actual collection name)
endpoint = f"{base_url}/bulletins-realtime/items"

# Parameters (if any)
params = {
    "lang": "en",  # Language parameter ('en' for English, 'fr' for French)
    # Add other parameters as needed
}

# Fetch data
response = requests.get(endpoint, params=params)

if response.status_code == 200:
    data = response.json()
    # Process the data as needed
    print(data)
else:
    print(f"Failed to fetch data: {response.status_code}")
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': None, 'properties': {'identifier': '20240928.UA.CWAO.00.UANT01_CWAO_280000___43525', 'datetime': '2024-09-28T00:00', 'type': 'UA', 'issuer_code': 'CWAO', 'issuer_name': None, 'issuer_country': None, 'issuing_office': 'AO', 'url': 'https://dd.weather.gc.ca/bulletins/alphanumeric/20240928/UA/CWAO/00/UANT01_CWAO_280000___43525'}, 'id': '20240928.UA.CWAO.00.UANT01_CWAO_280000___43525'}, {'type': 'Feature', 'geometry': None, 'properties': {'identifier': '20240928.UA.CWAO.00.UANT01_CWAO_280000___18633', 'datetime': '2024-09-28T00:00', 'type': 'UA', 'issuer_code': 'CWAO', 'issuer_name': None, 'issuer_country': None, 'issuing_office': 'AO', 'url': 'https://dd.weather.gc.ca/bulletins/alphanumeric/20240928/UA/CWAO/00/UANT01_CWAO_280000___18633'}, 'id': '20240928.UA.CWAO.00.UANT01_CWAO_280000___18633'}, {'type': 'Feature', 'geometry': None, 'properties': {'identifier': '20240928.SA.CYOC.00.SACN65_CYOC_280000___25932195',
# ...
